# %%
print('hello world')
# Out:
# hello world

# %%
from pymongo import MongoClient
from urllib.parse import quote_plus

# %%
! pip install pymongo[srv]
# Out:
# ...
# WARNING: pymongo 4.8.0 does not provide the extra 'srv'
# ...

# %%
client.close()

# %%
from pymongo import MongoClient
from urllib.parse import quote_plus

user_name = "giriprasathm1608"
user_password = "Girim1608@"

user_name_escaped = quote_plus(user_name)
user_password_escaped = quote_plus(user_password)

URI = f'mongodb+srv://{user_name_escaped}:{user_password_escaped}@fp-ml-data.ehr5y.mongodb.net/'

client = MongoClient(URI)
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[10], line 11
#       8 user_password_escaped = quote_plus(user_password)
#      10 URI = f'mongodb+srv://{user_name_escaped}:{user_password_escaped}@fp-ml-data.ehr5y.mongodb.net/'
# ---> 11 client = MongoClient(URI)
#
# File d:\fp_ml\Instrument-failure-prediction\venv\Lib\site-packages\pymongo\mongo_client.py:774, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     770 if timeout is not None:
#     771     timeout = common.validate_timeout_or_none_or_zero(
#     772         keyword_opts.cased_key("connecttimeoutms"), timeout
#     773     )
# --> 774 res = uri_parser.parse_uri(
#     775     entity,
#     776     port,
#     777     validate=True,
#     778     warn=True,
#     779     normalize=False,
#     780     connect_timeout=timeout,
# ...

# %%
client
# Out:
# MongoClient(host=['fp-ml-data-shard-00-02.ehr5y.mongodb.net:27017', 'fp-ml-data-shard-00-01.ehr5y.mongodb.net:27017', 'fp-ml-data-shard-00-00.ehr5y.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-102cn8-shard-0', tls=True)

# %%
import pandas as pd
data = pd.read_csv('fp_csv.csv')
df = pd.DataFrame(data)

# %%
df = df.drop(columns = ['Unnamed: 0'],axis = 1)

# %%
df['Difference Temperature'] = df['Difference Temperature'].round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UDI                      10000 non-null  int64
#  1   Product ID               10000 non-null  object
#  2   Type                     10000 non-null  object
#  3   Air temperature [K]      10000 non-null  float64
#  4   Process temperature [K]  10000 non-null  float64
#  5   Rotational speed [rpm]   10000 non-null  int64
#  6   Torque [Nm]              10000 non-null  float64
#  7   Tool wear [min]          10000 non-null  int64
#  8   Target                   10000 non-null  int64
#  9   Failure Type             10000 non-null  object
#  10  Noise Power              10000 non-null  float64
#  11  Noise                    10000 non-null  float64
#  12  Difference Temperature   10000 non-null  float64
# dtypes: float64(6), int64(4), object(3)
# ...

# %%
data = []
for i in range(df.shape[0]):
    data1 = {}
    data1['UDI']                      = int(df['UDI'][i])
    data1['Product ID']               = df['Product ID'][i]
    data1['Type']                     = df['Type'][i]
    data1['Air temperature [K]']      = float(df['Air temperature [K]'][i])
    data1['Process temperature [K]']  = float(df['Process temperature [K]'][i])
    data1['Rotational speed [rpm]']   = int(df['Rotational speed [rpm]'][i])
    data1['Torque [Nm]']              = float(df['Torque [Nm]'][i])
    data1['Tool wear [min]']          = int(df['Tool wear [min]'][i])
    data1['Target']                   = int(df['Target'][i])
    data1['Failure Type']             = df['Failure Type'][i]
    data1['Target']                   = int(df['Target'][i])
    data1['Noise Power']              = float(df['Noise Power'][i])
    data1['Noise']                    = float(df['Noise'][i])
    data1['Difference Temperature']   = float(df['Difference Temperature'][i])
    data.append(data1)
data
# Out:
# [{'UDI': 1,
#   'Product ID': 'M14860',
#   'Type': 'M',
#   'Air temperature [K]': 298.1,
#   'Process temperature [K]': 308.6,
#   'Rotational speed [rpm]': 1551,
#   'Torque [Nm]': 42.8,
#   'Tool wear [min]': 0,
#   'Target': 0,
#   'Failure Type': 'No Failure',
#   'Noise Power': 6951.59,
#   'Noise': 4091.59,
#   'Difference Temperature': 10.5},
#  {'UDI': 2,
#   'Product ID': 'L47181',
#   'Type': 'L',
#   'Air temperature [K]': 298.2,
#   'Process temperature [K]': 308.7,
#   'Rotational speed [rpm]': 1408,
#   'Torque [Nm]': 46.3,
#   'Tool wear [min]': 3,
#   'Target': 0,
#   'Failure Type': 'No Failure',
#   'Noise Power': 6826.72,
#   'Noise': 3966.72,
#   'Difference Temperature': 10.5},
#  {'UDI': 3,
#   'Product ID': 'L47182',
#   'Type': 'L',
#   'Air temperature [K]': 298.1,
#   'Process temperature [K]': 308.5,
#   'Rotational speed [rpm]': 1498,
#   'Torque [Nm]': 49.4,
#   'Tool wear [min]': 5,
#   'Target': 0,
#   'Failure Type': 'No Failure',
# ...

# %%
# push_mongodb = client['log']['product'].insert_many(data)
# push_mongodb.acknowledged
# Out:
# True

# %%
pull = client['log']['product'].find()
pull_data = [i for i in pull]
len(pull_data)
# Out:
# 10000

# %%
#machine learning

# %%
from pymongo import MongoClient
from urllib.parse import quote_plus

user_name = "giriprasathm1608"
user_password = "Girim1608@"

user_name_escaped = quote_plus(user_name)
user_password_escaped = quote_plus(user_password)

URI = f"mongodb+srv://{user_name_escaped}:{user_password_escaped}@fp-ml-data.ehr5y.mongodb.net/"
client = MongoClient(URI)
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[11], line 11
#       8 user_password_escaped = quote_plus(user_password)
#      10 URI = f"mongodb+srv://{user_name_escaped}:{user_password_escaped}@fp-ml-data.ehr5y.mongodb.net/"
# ---> 11 client = MongoClient(URI)
#
# File d:\fp_ml\Instrument-failure-prediction\venv\Lib\site-packages\pymongo\mongo_client.py:774, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     770 if timeout is not None:
#     771     timeout = common.validate_timeout_or_none_or_zero(
#     772         keyword_opts.cased_key("connecttimeoutms"), timeout
#     773     )
# --> 774 res = uri_parser.parse_uri(
#     775     entity,
#     776     port,
#     777     validate=True,
#     778     warn=True,
#     779     normalize=False,
#     780     connect_timeout=timeout,
# ...

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier 
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,roc_curve,roc_auc_score, auc
import matplotlib.pyplot as plt

# %%
logistic_model = LogisticRegression()
K_neighbor_model = KNeighborsClassifier()
decision_tree_model = DecisionTreeClassifier()
random_forest_model = RandomForestClassifier()
gbc_model = GradientBoostingClassifier()
adaboost_model = AdaBoostClassifier()
models = [logistic_model,K_neighbor_model,decision_tree_model,random_forest_model,gbc_model,adaboost_model]

# %%
import pandas as pd
pull = client['log']['product'].find()
pull_data = [i for i in pull]

# %%
import pandas as pd
data = pd.read_csv('fp_csv.csv')
ml_df = pd.DataFrame(data)

# %%
ml_df
# Out:
#       Unnamed: 0    UDI Product ID Type  Air temperature [K]  \
# 0              0      1     M14860    M                298.1
# 1              1      2     L47181    L                298.2
# 2              2      3     L47182    L                298.1
# 3              3      4     L47183    L                298.2
# 4              4      5     L47184    L                298.2
# ...          ...    ...        ...  ...                  ...
# 9995        9995   9996     M24855    M                298.8
# 9996        9996   9997     H39410    H                298.9
# 9997        9997   9998     M24857    M                299.0
# 9998        9998   9999     H39412    H                299.0
# 9999        9999  10000     M24859    M                299.0
#
#       Process temperature [K]  Rotational speed [rpm]  Torque [Nm]  \
# 0                       308.6                    1551         42.8
# 1                       308.7                    1408         46.3
# ...

# %%
ml_df = ml_df.drop(columns = ['Unnamed: 0','UDI','Product ID'], axis = 1)

# %%
ml_df
# Out:
#      Type  Air temperature [K]  Process temperature [K]  \
# 0       M                298.1                    308.6
# 1       L                298.2                    308.7
# 2       L                298.1                    308.5
# 3       L                298.2                    308.6
# 4       L                298.2                    308.7
# ...   ...                  ...                      ...
# 9995    M                298.8                    308.4
# 9996    H                298.9                    308.4
# 9997    M                299.0                    308.6
# 9998    H                299.0                    308.7
# 9999    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 0                       1551         42.8                0       0
# 1                       1408         46.3                3       0
# 2                       1498         49.4                5       0
# ...

# %%
X = ml_df.drop(columns = ['Target','Failure Type'])
y = ml_df['Target']

# %%
import numpy as np 
label_encoder = LabelEncoder()
scaler = StandardScaler()

num = scaler.fit_transform(X[['Air temperature [K]', 'Process temperature [K]',
    'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]','Noise Power', 'Noise', 'Difference Temperature']])
cat = label_encoder.fit_transform(X['Type'])

X = np.column_stack((num, cat))

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.20, random_state=100,stratify = y)
print(len(X_train),len(X_test),len(y_train),len(y_test))
# Out:
# 8000 2000 8000 2000

# %%
evaluation_test = []
evaluation_train =[]
#logistic model
for model in models:

    print('model name =', model)
    #model train
    model.fit(X_train,y_train)

    # model prediction
    y_pred_test = model.predict(X_test)

    #model evaluation on test data
    test_accuracy = accuracy_score(y_test,y_pred_test)
    test_precision_score = precision_score(y_test,y_pred_test)
    test_recall_score = recall_score(y_test,y_pred_test)
    test_f1_score = f1_score(y_test,y_pred_test)
    test_conf_matrix = confusion_matrix(y_test,y_pred_test)
    tn, fp, fn, tp = confusion_matrix(y_test,y_pred_test).ravel()
    specificity_test = (tn/(fp+tn))

    print('Testing Evaluation--------------------------------------------------------------------')
    print('test_accuracy',test_accuracy)
    print('test_precision_score',test_precision_score)
    print('test_recall_score',test_recall_score)
    print('test_f1_score',test_f1_score)
    print('test_conf_matrix',test_conf_matrix)
    print('specificity_test: ',specificity_test)
    
    # Plot ROC curve
    y_prob_test = model.predict_proba(X_test)[:,1] 
    fpr,tpr,thershold = roc_curve(y_test, y_prob_test)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    print('roc_auc',roc_auc)
    plt.show()

    data_test={'model name': model,
              'test_accuracy':test_accuracy,
              'test_precision_score':test_precision_score,
              'test_recall_score':test_recall_score,
              'test_f1_score':test_f1_score,
              'test_conf_matrix':str(test_conf_matrix),
              'roc_auc':roc_auc}
    
    evaluation_test.append(data_test)

    #model evaluation in train data
    y_pred_train = model.predict(X_train)

    train_accuracy = accuracy_score(y_train,y_pred_train)
    train_precision_score = precision_score(y_train,y_pred_train)
    train_recall_score = recall_score(y_train,y_pred_train)
    train_f1_score = f1_score(y_train,y_pred_train)
    train_conf_matrix = confusion_matrix(y_train,y_pred_train)
    tn, fp, fn, tp = confusion_matrix(y_train,y_pred_train).ravel()
    specificity_train = (tn/(fp+tn))

    print('Training Evaluation--------------------------------------------------------------------')
    print('train_accuracy',train_accuracy)
    print('train_precision_score',train_precision_score)
    print('train_recall_score',train_recall_score)
    print('train_f1_score',train_f1_score)
    print('train_conf_matrix',train_conf_matrix)
    print('specificity_train: ',specificity_train)

    # Plot ROC curve
    y_prob_train = model.predict_proba(X_train)[:,1] 
    fpr,tpr,thershold = roc_curve(y_train, y_prob_train)
    roc_auc_train = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc_train)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    print('roc_auc_train',roc_auc_train)
    plt.show()
    data_train = {'model name' : model,
                'train_accuracy':train_accuracy,
                'train_precision_score':train_precision_score,
                'train_recall_score':train_recall_score,
                'train_f1_score':train_f1_score,
                'train_conf_matrix':str(train_conf_matrix),
                'train_roc_auc':roc_auc_train}
    evaluation_train.append(data_train)
# Out:
# model name = LogisticRegression()
# d:\fp_ml\Instrument-failure-prediction\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Testing Evaluation--------------------------------------------------------------------
# test_accuracy 0.9685
# test_precision_score 0.6
# test_recall_score 0.22058823529411764
# test_f1_score 0.3225806451612903
# test_conf_matrix [[1922   10]
#  [  53   15]]
# specificity_test:  0.994824016563147
# roc_auc 0.9246057118499573
# ...

# %%
evaluation_test
# Out:
# [{'model name': LogisticRegression(),
#   'test_accuracy': 0.9725,
#   'test_precision_score': np.float64(0.6153846153846154),
#   'test_recall_score': np.float64(0.26229508196721313),
#   'test_f1_score': np.float64(0.367816091954023),
#   'test_conf_matrix': '[[1929   10]\n [  45   16]]',
#   'roc_auc': np.float64(0.913154490653455)},
#  {'model name': KNeighborsClassifier(),
#   'test_accuracy': 0.9745,
#   'test_precision_score': np.float64(0.6666666666666666),
#   'test_recall_score': np.float64(0.32786885245901637),
#   'test_f1_score': np.float64(0.43956043956043955),
#   'test_conf_matrix': '[[1929   10]\n [  41   20]]',
#   'roc_auc': np.float64(0.867782953863323)},
#  {'model name': DecisionTreeClassifier(),
#   'test_accuracy': 0.9835,
#   'test_precision_score': np.float64(0.7121212121212122),
#   'test_recall_score': np.float64(0.7704918032786885),
#   'test_f1_score': np.float64(0.7401574803149606),
#   'test_conf_matrix': '[[1920   19]\n [  14   47]]',
# ...

# %%
df_evaluation_test = pd.DataFrame(evaluation_test)
df_evaluation_train = pd.DataFrame(evaluation_train)

# %%
df_evaluation_test
# Out:
#                                           model name  test_accuracy  \
# 0                               LogisticRegression()         0.9685
# 1                             KNeighborsClassifier()         0.9750
# 2                           DecisionTreeClassifier()         0.9840
# 3  (DecisionTreeClassifier(max_features='sqrt', r...         0.9900
# 4  ([DecisionTreeRegressor(criterion='friedman_ms...         0.9910
# 5  (DecisionTreeClassifier(max_depth=1, random_st...         0.9740
#
#    test_precision_score  test_recall_score  test_f1_score  \
# 0              0.600000           0.220588       0.322581
# 1              0.846154           0.323529       0.468085
# 2              0.757143           0.779412       0.768116
# 3              0.961538           0.735294       0.833333
# 4              0.980769           0.750000       0.850000
# 5              0.690476           0.426471       0.527273
#
#               test_conf_matrix   roc_auc
# ...

# %%
df_evaluation_train
# Out:
#                                           model name  train_accuracy  \
# 0                               LogisticRegression()        0.971750
# 1                             KNeighborsClassifier()        0.978625
# 2                           DecisionTreeClassifier()        1.000000
# 3  (DecisionTreeClassifier(max_features='sqrt', r...        1.000000
# 4  ([DecisionTreeRegressor(criterion='friedman_ms...        0.995125
# 5  (DecisionTreeClassifier(max_depth=1, random_st...        0.980250
#
#    train_precision_score  train_recall_score  train_f1_score  \
# 0               0.722772            0.269373        0.392473
# 1               0.916667            0.405904        0.562660
# 2               1.000000            1.000000        1.000000
# 3               1.000000            1.000000        1.000000
# 4               0.995726            0.859779        0.922772
# 5               0.795812            0.560886        0.658009
#
#              train_conf_matrix  train_roc_auc
# ...

# %%
#gradient boosting model is choosed

# %%
# from xgboost import XGBClassifier


# # create model instance
# bst = XGBClassifier(n_estimators=2, max_depth=2, learning_rate=1, objective='binary:logistic')
# # fit model
# bst.fit(X_train, y_train)
# # make predictions
# y_pred_test = bst.predict(X_test)

# %%
# #model evaluation on test data
# test_accuracy = accuracy_score(y_test,y_pred_test)
# test_precision_score = precision_score(y_test,y_pred_test)
# test_recall_score = recall_score(y_test,y_pred_test)
# test_f1_score = f1_score(y_test,y_pred_test)
# test_conf_matrix = confusion_matrix(y_test,y_pred_test)

# print('Testing Evaluation--------------------------------------------------------------------')
# print('test_accuracy',test_accuracy)
# print('test_precision_score',test_precision_score)
# print('test_recall_score',test_recall_score)
# print('test_f1_score',test_f1_score)
# print('test_conf_matrix',test_conf_matrix)
# Out:
# Testing Evaluation--------------------------------------------------------------------
# test_accuracy 0.9835
# test_precision_score 0.8333333333333334
# test_recall_score 0.5737704918032787
# test_f1_score 0.6796116504854369
# test_conf_matrix [[1932    7]
#  [  26   35]]

# %%
import numpy as np
X = ml_df.drop(columns = ['Target','Failure Type'])
y = ml_df[['Target','Failure Type']]

label_encoder = LabelEncoder()
scaler = StandardScaler()

num = scaler.fit_transform(X[['Air temperature [K]', 'Process temperature [K]',
    'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]','Noise Power', 'Noise', 'Difference Temperature']])
cat = label_encoder.fit_transform(X['Type'])

y['Failure Type'] = label_encoder.fit_transform(y['Failure Type'])
X = np.column_stack((num, cat))
# Out:
# C:\Users\GIRI\AppData\Local\Temp\ipykernel_6204\3421038615.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['Failure Type'] = label_encoder.fit_transform(y['Failure Type'])

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y,
                                                 test_size = 0.20,
                                                 random_state=100,
                                                 stratify = y)
print(len(X_train),len(X_test),len(y_train),len(y_test))
# Out:
# 8000 2000 8000 2000

# %%
y_train_1 = y_train['Target']
y_train_2 = y_train['Failure Type']
y_test_1 = y_test['Target']
y_test_2 = y_test['Failure Type']

# %%
from scipy.stats import uniform, randint
from imblearn.over_sampling import SMOTE
model = GradientBoostingClassifier(random_state=100)

param_distributions = {
    'n_estimators': randint(100, 301),  # Random integers between 100 and 300
    'learning_rate': uniform(0.01, 0.1),  # Random floats between 0.01 and 0.11
    'max_depth': randint(3, 6),  # Random integers between 3 and 5
    'min_samples_split': randint(2, 11),  # Random integers between 2 and 10
    'min_samples_leaf': randint(1, 5),  # Random integers between 1 and 4
    'subsample': uniform(0.8, 0.2)  # Random floats between 0.8 and 1.0
}

# Step 4: Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_distributions, 
                                    n_iter=10, cv=3, n_jobs=-1, verbose=2, scoring='recall', 
                                    random_state=100)


# grid_searchcv = GridSearchCV(
#     estimator =  model,
#     param_grid = param_grid,
#     scoring ='recall',
#     n_jobs = -1,
#     cv = 5,
#     verbose=2)



X_sampled,y_sampled = SMOTE().fit_resample(X_train,y_train)
random_search.fit(X_sampled,y_sampled)
model = random_search.best_estimator_
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
conf_matrix = confusion_matrix(y_test,y_pred)
tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
specificity = tn/(fp+tn)

print('accuracy = ',accuracy)
print('precision = ',precision)
print('recall = ',recall)
print('specificity = ',specificity)
print('f1 = ',f1)
print('conf_matrix = ',conf_matrix)

y_proba = model.predict_proba(X_test)[:,1]
fpr,tpr,thershold = roc_curve(y_test, y_proba)
auc_score = auc(fpr,tpr)

print('auc_score = ',auc_score)

# plt.figure()
# plt.plot(fpr,tpr,lw = 2, color = 'darkorange', label = 'ROC SCORE = (%0.2f)' % auc_score)
# plt.plot([0,1],[0,1], color = 'navy', linestyle = '--')
# plt.xlim([0.0,1.0])
# plt.ylim([0.0,1.05])
# plt.legend(loc = 'lower right')
# plt.title('ROC CURVE')
# plt.xlabel('false postive rate')
# plt.ylabel('True positive rate')
# plt.show()
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# accuracy =  0.986
# precision =  0.7777777777777778
# recall =  0.8235294117647058
# specificity =  0.9917184265010351
# f1 =  0.8
# conf_matrix =  [[1916   16]
#  [  12   56]]
# auc_score =  0.988095238095238

# %%
random_search.best_params_
# Out:
# {'learning_rate': np.float64(0.09904115634420757),
#  'max_depth': 5,
#  'min_samples_leaf': 1,
#  'min_samples_split': 10,
#  'n_estimators': 262,
#  'subsample': np.float64(0.9781091889457009)}

# %%
accuracy =  0.991
precision =  0.9807692307692307
recall =  0.75
specificity =  0.9994824016563147
f1 =  0.85
conf_matrix =  [[1931    1]
 [  17   51]]
auc_score =  0.9784359395932286

# %%
from imblearn.over_sampling import SMOTE
model = RandomForestClassifier(max_depth= 25,
        min_samples_leaf= 1,
        min_samples_split= 6,
        n_estimators= 198,
        random_state = 100)

param_distributions = {
    'n_estimators': randint(100, 201),  # Number of trees in the forest
    'max_depth': randint(10, 51),      # Maximum depth of each tree
    'min_samples_split': randint(2, 11),  # Minimum number of samples to split an internal node
    'min_samples_leaf': randint(1, 11)  # Minimum number of samples at a leaf node
}

# Step 4: Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_distributions, 
                                    n_iter=10, cv=5, n_jobs=-1, verbose=2, scoring='recall', 
                                    random_state=100)



X_sampled,y_sampled = SMOTE().fit_resample(X_train,y_train)
random_search.fit(X_sampled,y_sampled)
model = random_search.best_estimator_
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
conf_matrix = confusion_matrix(y_test,y_pred)
tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
specificity = tn/(fp+tn)

print('accuracy = ',accuracy)
print('precision = ',precision)
print('recall = ',recall)
print('specificity = ',specificity)
print('f1 = ',f1)
print('conf_matrix = ',conf_matrix)

y_proba = model.predict_proba(X_test)[:,1]
fpr,tpr,thershold = roc_curve(y_test, y_proba)
auc_score = auc(fpr,tpr)

print('auc_score = ',auc_score)

# plt.figure()
# plt.plot(fpr,tpr,lw = 2, color = 'darkorange', label = 'ROC SCORE = (%0.2f)' % auc_score)
# plt.plot([0,1],[0,1], color = 'navy', linestyle = '--')
# plt.xlim([0.0,1.0])
# plt.ylim([0.0,1.05])
# plt.legend(loc = 'lower right')
# plt.title('ROC CURVE')
# plt.xlabel('false postive rate')
# plt.ylabel('True positive rate')
# plt.show()
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# accuracy =  0.985
# precision =  0.7435897435897436
# recall =  0.8529411764705882
# specificity =  0.989648033126294
# f1 =  0.7945205479452054
# conf_matrix =  [[1912   20]
#  [  10   58]]
# auc_score =  0.980947813908172

# %%
random_search.best_params_
# Out:
# {'max_depth': 25,
#  'min_samples_leaf': 1,
#  'min_samples_split': 6,
#  'n_estimators': 198}

# %%
accuracy =  0.9915
precision =  0.9811320754716981
recall =  0.7647058823529411
specificity =  0.9994824016563147
f1 =  0.859504132231405
conf_matrix =  [[1931    1]
 [  16   52]]
auc_score =  0.9783864632809646

# %%
from imblearn.over_sampling import SMOTE
model = RandomForestClassifier(max_depth= 25,
        min_samples_leaf= 1,
        min_samples_split= 6,
        n_estimators= 198,
        random_state = 42)

X_sampled,y_sampled = SMOTE().fit_resample(X_train,y_train)
model.fit(X_sampled,y_sampled)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
conf_matrix = confusion_matrix(y_test,y_pred)
tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
specificity = tn/(fp+tn)

print('accuracy = ',accuracy)
print('precision = ',precision)
print('recall = ',recall)
print('specificity = ',specificity)
print('f1 = ',f1)
print('conf_matrix = ',conf_matrix)

y_proba = model.predict_proba(X_test)[:,1]
fpr,tpr,thershold = roc_curve(y_test, y_proba)
auc_score = auc(fpr,tpr)

print('auc_score = ',auc_score)

# plt.figure()
# plt.plot(fpr,tpr,lw = 2, color = 'darkorange', label = 'ROC SCORE = (%0.2f)' % auc_score)
# plt.plot([0,1],[0,1], color = 'navy', linestyle = '--')
# plt.xlim([0.0,1.0])
# plt.ylim([0.0,1.05])
# plt.legend(loc = 'lower right')
# plt.title('ROC CURVE')
# plt.xlabel('false postive rate')
# plt.ylabel('True positive rate')
# plt.show()

y_pred_train = model.predict(X_train)

train_accuracy = accuracy_score(y_train,y_pred_train)
train_precision_score = precision_score(y_train,y_pred_train)
train_recall_score = recall_score(y_train,y_pred_train)
train_f1_score = f1_score(y_train,y_pred_train)
train_conf_matrix = confusion_matrix(y_train,y_pred_train)
tn, fp, fn, tp = confusion_matrix(y_train,y_pred_train).ravel()
specificity_train = (tn/(fp+tn))

print('Training Evaluation--------------------------------------------------------------------')
print('train_accuracy',train_accuracy)
print('train_precision_score',train_precision_score)
print('train_recall_score',train_recall_score)
print('train_f1_score',train_f1_score)
print('train_conf_matrix',train_conf_matrix)
print('specificity_train: ',specificity_train)

# Plot ROC curve
y_prob_train = model.predict_proba(X_train)[:,1] 
fpr,tpr,thershold = roc_curve(y_train, y_prob_train)
roc_auc_train = auc(fpr, tpr)
print('roc_auc_train: ',roc_auc_train)
# Out:
# accuracy =  0.9855
# precision =  0.7532467532467533
# recall =  0.8529411764705882
# specificity =  0.9901656314699793
# f1 =  0.8
# conf_matrix =  [[1913   19]
#  [  10   58]]
# auc_score =  0.9858726099135305
# Training Evaluation--------------------------------------------------------------------
# train_accuracy 0.999875
# train_precision_score 0.9963235294117647
# train_recall_score 1.0
# train_f1_score 0.998158379373849
# train_conf_matrix [[7728    1]
#  [   0  271]]
# specificity_train:  0.9998706171561651
# roc_auc_train:  0.9999999999999999

# %%
from imblearn.over_sampling import SMOTE
model = GradientBoostingClassifier(random_state=42,
        learning_rate= 0.005,
        max_depth= 15,
        min_samples_leaf= 1,
        min_samples_split=10,
        n_estimators=500,
        subsample= 0.2)

X_sampled,y_sampled = SMOTE().fit_resample(X_train,y_train)
model.fit(X_sampled,y_sampled)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
conf_matrix = confusion_matrix(y_test,y_pred)
tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
specificity = tn/(fp+tn)

print('accuracy = ',accuracy)
print('precision = ',precision)
print('recall = ',recall)
print('specificity = ',specificity)
print('f1 = ',f1)
print('conf_matrix = ',conf_matrix)

y_proba = model.predict_proba(X_test)[:,1]
fpr,tpr,thershold = roc_curve(y_test, y_proba)
auc_score = auc(fpr,tpr)

print('auc_score = ',auc_score)

# plt.figure()
# plt.plot(fpr,tpr,lw = 2, color = 'darkorange', label = 'ROC SCORE = (%0.2f)' % auc_score)
# plt.plot([0,1],[0,1], color = 'navy', linestyle = '--')
# plt.xlim([0.0,1.0])
# plt.ylim([0.0,1.05])
# plt.legend(loc = 'lower right')
# plt.title('ROC CURVE')
# plt.xlabel('false postive rate')
# plt.ylabel('True positive rate')
# plt.show()

y_pred_train = model.predict(X_train)

train_accuracy = accuracy_score(y_train,y_pred_train)
train_precision_score = precision_score(y_train,y_pred_train)
train_recall_score = recall_score(y_train,y_pred_train)
train_f1_score = f1_score(y_train,y_pred_train)
train_conf_matrix = confusion_matrix(y_train,y_pred_train)
tn, fp, fn, tp = confusion_matrix(y_train,y_pred_train).ravel()
specificity_train = (tn/(fp+tn))

print('Training Evaluation--------------------------------------------------------------------')
print('train_accuracy',train_accuracy)
print('train_precision_score',train_precision_score)
print('train_recall_score',train_recall_score)
print('train_f1_score',train_f1_score)
print('train_conf_matrix',train_conf_matrix)
print('specificity_train: ',specificity_train)

# Plot ROC curve
y_prob_train = model.predict_proba(X_train)[:,1] 
fpr,tpr,thershold = roc_curve(y_train, y_prob_train)
roc_auc_train = auc(fpr, tpr)
print('roc_auc_train: ',roc_auc_train)
# Out:
# accuracy =  0.975
# precision =  0.5882352941176471
# recall =  0.8823529411764706
# specificity =  0.9782608695652174
# f1 =  0.7058823529411765
# conf_matrix =  [[1890   42]
#  [   8   60]]
# auc_score =  0.9860629034222386
# Training Evaluation--------------------------------------------------------------------
# train_accuracy 0.989375
# train_precision_score 0.7703488372093024
# train_recall_score 0.977859778597786
# train_f1_score 0.8617886178861789
# train_conf_matrix [[7650   79]
#  [   6  265]]
# specificity_train:  0.9897787553370423
# roc_auc_train:  0.9992079478305457

# %%
from sklearn.ensemble import VotingClassifier

gbc = GradientBoostingClassifier(random_state=42,
        learning_rate= 0.099,
        max_depth= 5,
        min_samples_leaf= 1,
        min_samples_split=10,
        n_estimators=262,
        subsample= 0.097)

rfc = RandomForestClassifier(max_depth= 25,
        min_samples_leaf= 1,
        min_samples_split= 6,
        n_estimators= 198,
        random_state = 42)

ensemble_model = VotingClassifier(
    estimators=[
        ('Random forest classifier',rfc),
        ('Gradient Bossting Classifier',gbc)
        ],
        voting = 'soft'
)

X_sampled,y_sampled = SMOTE().fit_resample(X_train,y_train_1)
ensemble_model.fit(X_sampled,y_sampled)
y_pred = ensemble_model.predict(X_test)

#evaluation test data

accuracy = accuracy_score(y_test_1,y_pred)
precision = precision_score(y_test_1,y_pred)
recall = recall_score(y_test_1,y_pred)
f1 = f1_score(y_test_1,y_pred)
conf_matrix = confusion_matrix(y_test_1,y_pred)

#specificity
tn, fp, fn, tp = confusion_matrix(y_test_1,y_pred).ravel()
specificity = tn/(fp+tn)

#roc curve
# y_proba = ensemble_model.predict_proba(X_test)[:,1]
# fpr,tpr,thershold = roc_curve(y_test_1, y_proba)
# auc_score = auc(fpr,tpr)

print('accuracy = ',accuracy)
print('precision = ',precision)
print('recall = ',recall)
print('specificity = ',specificity)
print('f1 = ',f1)
print('conf_matrix = ',conf_matrix)
# print('auc_score = ',auc_score)

#training data testing

print('Training Evaluation--------------------------------------------------------------------')
y_pred_train = ensemble_model.predict(X_train)

#evaluation train data

train_accuracy = accuracy_score(y_train_1,y_pred_train)
train_precision_score = precision_score(y_train_1,y_pred_train)
train_recall_score = recall_score(y_train_1,y_pred_train)
train_f1_score = f1_score(y_train_1,y_pred_train)
train_conf_matrix = confusion_matrix(y_train_1,y_pred_train)

#specificity
tn, fp, fn, tp = confusion_matrix(y_train_1,y_pred_train).ravel()
specificity_train = (tn/(fp+tn))

#roc curve
# y_prob_train = ensemble_model.predict_proba(X_train)[:,1] 
# fpr,tpr,thershold = roc_curve(y_train, y_prob_train)
# roc_auc_train = auc(fpr, tpr)


print('train_accuracy',train_accuracy)
print('train_precision_score',train_precision_score)
print('train_recall_score',train_recall_score)
print('train_f1_score',train_f1_score)
print('train_conf_matrix',train_conf_matrix)
print('specificity_train: ',specificity_train)
# print('roc_auc_train: ',roc_auc_train)
# Out:
# accuracy =  0.975
# precision =  0.6022727272727273
# recall =  0.7794117647058824
# specificity =  0.9818840579710145
# f1 =  0.6794871794871795
# conf_matrix =  [[1897   35]
#  [  15   53]]
# Training Evaluation--------------------------------------------------------------------
# train_accuracy 0.998875
# train_precision_score 0.9746376811594203
# train_recall_score 0.992619926199262
# train_f1_score 0.9835466179159049
# train_conf_matrix [[7722    7]
#  [   2  269]]
# specificity_train:  0.9990943200931557

# %%
X_train_2 = np.column_stack((X_train,y_train_1))
X_test_2 = np.column_stack((X_test,y_pred))

# %%
from imblearn.over_sampling import RandomOverSampler as ROS
from sklearn.metrics import classification_report

# X_sampled_2,y_sampled_2 = ROS().fit_resample(X_train_2,y_train_2)
rfc.fit(X_train_2,y_train_2)
y_pred_2 = rfc.predict(X_test_2)

#evaluation test data

accuracy = accuracy_score(y_test_2,y_pred_2)
# precision = precision_score(y_test_2,y_pred_2)
# recall = recall_score(y_test_2,y_pred_2)
# f1 = f1_score(y_test_2,y_pred_2)
conf_matrix = confusion_matrix(y_test_2,y_pred_2)
class_report = classification_report(y_test_2,y_pred_2)
#specificity
# tn, fp, fn, tp = confusion_matrix(y_test_2,y_pred_2).ravel()
# specificity = tn/(fp+tn)

#roc curve
# y_proba = ensemble_model.predict_proba(X_test)[:,1]
# fpr,tpr,thershold = roc_curve(y_test_1, y_proba)
# auc_score = auc(fpr,tpr)

print('accuracy = ',accuracy)
print('conf_matrix = ',conf_matrix)
print('class_report = ',class_report)
# print('precision = ',precision)
# print('recall = ',recall)
# print('specificity = ',specificity)
# print('f1 = ',f1)
# print('auc_score = ',auc_score)

#training data testing

print('Training Evaluation--------------------------------------------------------------------')
y_pred_train_2 = rfc.predict(X_train_2)

#evaluation train data

train_accuracy = accuracy_score(y_train_2,y_pred_train_2)
train_conf_matrix = confusion_matrix(y_train_2,y_pred_train_2)
train_class_report = classification_report(y_train_2,y_pred_train_2)
# train_precision_score = precision_score(y_train_2,y_pred_train_2)
# train_recall_score = recall_score(y_train_2,y_pred_train_2)
# train_f1_score = f1_score(y_train_2,y_pred_train_2)


#specificity
# tn, fp, fn, tp = confusion_matrix(y_train_2,y_pred_train_2).ravel()
# specificity_train = (tn/(fp+tn))

#roc curve
# y_prob_train = ensemble_model.predict_proba(X_train)[:,1] 
# fpr,tpr,thershold = roc_curve(y_train, y_prob_train)
# roc_auc_train = auc(fpr, tpr)


print('train_accuracy',train_accuracy)
print('train_conf_matrix',train_conf_matrix)
print('class report = ', train_class_report)
# print('train_precision_score',train_precision_score)
# print('train_recall_score',train_recall_score)
# print('train_f1_score',train_f1_score)
# print('specificity_train: ',specificity_train)
# print('roc_auc_train: ',roc_auc_train)
# Out:
# d:\fp_ml\Instrument-failure-prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\fp_ml\Instrument-failure-prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# d:\fp_ml\Instrument-failure-prediction\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
y_test_2.to_frame().value_counts()
# Out:
# Failure Type
# 1               1930
# 0                 22
# 3                 19
# 2                 16
# 5                  9
# 4                  4
# Name: count, dtype: int64
